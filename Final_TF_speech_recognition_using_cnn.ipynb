# %%
# To verify CUDA
# !/usr/local/cuda/bin/nvcc --version
# To Print GPU info
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0
# Thu Apr  1 21:26:54 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Define helper functions
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()

# use this to upload files
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)

# use this to download a file  
def download(path):
  from google.colab import files
  files.download(path)

# %%
# Mounting Google Drive
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# This creates a symbolic link so that the path /content/gdrive/My\ Drive/ is equal to /mydrive
# !ln -s /content/gdrive/My\ Drive/ /mydrive

# %%
# cd back into the darknet folder to run detections
###%cd darknet

# %%
# Copy over both datasets into the root directory of the Colab VM
###!cp /mydrive/yolov4/obj.zip ../
###!cp /mydrive/yolov4/test.zip ../

# %%
# Unzip the datasets and their contents so that they are now in /darknet/data/ folder
###!unzip ../obj.zip -d data/
###!unzip ../test.zip -d data/

# %%
# !ls
# %cd /mydrive
# Out:
# bin	 datalab  home	 lib64	mydrive  root  srv		  tmp	 var
# boot	 dev	  lib	 media	opt	 run   sys		  tools
# content  etc	  lib32  mnt	proc	 sbin  tensorflow-1.15.2  usr
# /content/gdrive/My Drive

# %%
import os
# !pwd
for dirname, _, filenames in os.walk('./tensorflow-speech-recognition-challenge/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/gdrive/My Drive
# ./tensorflow-speech-recognition-challenge/link_to_gcp_credits_form.txt
# ./tensorflow-speech-recognition-challenge/sample_submission.7z
# ./tensorflow-speech-recognition-challenge/test.7z
# ./tensorflow-speech-recognition-challenge/train.7z
# ./tensorflow-speech-recognition-challenge/speech-classification-using-cnn.ipynb

# %%
from os.path import isdir, join
from pathlib import Path
import pandas as pd

# Math
import numpy as np
from scipy.fftpack import fft
from scipy import signal
from scipy.io import wavfile
import librosa

from sklearn.decomposition import PCA

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import IPython.display as ipd
import librosa.display

import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import pandas as pd

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import os
import librosa   #for audio processing
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile #for audio processing
import warnings
warnings.filterwarnings("ignore")

# %%
# !pwd
# Out:
# /content/gdrive/My Drive

# %%
#!unzip ./tensorflow-speech-recognition-challenge/test.7z -d /mydrive

# %%
# !apt-get install -y p7zip-full
!7z x ./tensorflow-speech-recognition-challenge/train.7z
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-6).
# 0 upgraded, 0 newly installed, 0 to remove and 30 not upgraded.
#
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 1121103842 bytes (1070 MiB)
#
# Extracting archive: ./tensorflow-speech-recognition-challenge/train.7z
# --
# Path = ./tensorflow-speech-recognition-challenge/train.7z
# Type = 7z
# Physical Size = 1121103842
# Headers Size = 389133
# Method = Delta LZMA2:24
# Solid = +
# Blocks = 2
#
# Everything is Ok
#
# Folders: 33
# Files: 64732
# Size:       2055161498
# Compressed: 1121103842

# %%
#train_audio_path = '/tensorflow-speech-recognition-challenge/train/audio/'
train_audio_path = 'train/audio/'
# !ls
# Out:
#  14.0.4734.1000_ProfessionalPlus_volume_x86_en-us.iso
# 'Colab Notebooks'
#  Deepfake
#  Deepfake_detection_using_deep_learning-master
#  Learning-to-See-Moving-Objects-in-the-Dark-master
#  Models
#  results
#  tensorflow-speech-recognition-challenge
#  train
#  videos
#  yolov4

# %%
#train_audio_path = '/tensorflow-speech-recognition-challenge/train/audio/'
train_audio_path = 'train/audio/'
filename = 'yes/0a7c2a8d_nohash_0.wav'
sample_rate, samples = wavfile.read(str(train_audio_path) + filename)
fig = plt.figure(figsize=(14, 8))
ax1 = fig.add_subplot(211)
ax1.set_title('Raw wave of ' + 'train/audio/yes/0a7c2a8d_nohash_0.wav')
ax1.set_xlabel('time')
ax1.set_ylabel('Amplitude')
ax1.plot(np.linspace(0, sample_rate/len(samples), sample_rate), samples)
print(sample_rate)
print(len(samples))
# Out:
# 16000
# 16000

# %%
ipd.Audio(samples, rate=sample_rate)
print(sample_rate)
np.array(samples, dtype='float64')
# Out:
# 16000
# array([ 14.,  -7., -14., ...,  19.,  20.,  27.])

# %%
samples=np.array(samples, dtype='float64')

samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples, rate=8000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
labels=os.listdir(train_audio_path)

#find count of each label and plot bar graph
no_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    no_of_recordings.append(len(waves))
    
#plot
plt.figure(figsize=(30,5))
index = np.arange(len(labels))
plt.bar(index, no_of_recordings)
plt.xlabel('Commands', fontsize=12)
plt.ylabel('No of recordings', fontsize=12)
plt.xticks(index, labels, fontsize=15, rotation=60)
plt.title('No. of recordings for each command')
plt.show()

labels=["yes", "no", "up", "down", "left", "right", "on", "off", "stop", "go"]

# %%
duration_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
        sample_rate, samples = wavfile.read(train_audio_path + '/' + label + '/' + wav)
        duration_of_recordings.append(float(len(samples)/sample_rate))
    
plt.hist(np.array(duration_of_recordings))
# Out:
# (array([1.5000e+01, 3.0000e+01, 4.4000e+01, 1.3800e+02, 1.3600e+02,
#         1.7900e+02, 3.6600e+02, 4.3400e+02, 5.9300e+02, 2.1747e+04]),
#  array([0.418 , 0.4762, 0.5344, 0.5926, 0.6508, 0.709 , 0.7672, 0.8254,
#         0.8836, 0.9418, 1.    ]),
#  <a list of 10 Patch objects>)

# %%
#train_audio_path = './tensorflow-speech-recognition-challenge/'
train_audio_path = 'train/audio/'

all_wave = []
all_label = []
for label in labels:
    print(label)
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
        samples, sample_rate = librosa.load(train_audio_path + '/' + label + '/' + wav, sr = 16000)
        samples = librosa.resample(samples, sample_rate, 8000)
        if(len(samples)== 8000) : 
            all_wave.append(samples)
            all_label.append(label)
# Out:
# yes
# no
# up
# down
# left
# right
# on
# off
# stop
# go

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y=le.fit_transform(all_label)
classes= list(le.classes_)

# %%
from keras.utils import np_utils
y=np_utils.to_categorical(y, num_classes=len(labels))

# %%
all_wave = np.array(all_wave).reshape(-1,8000,1)

# %%
from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(np.array(all_wave),np.array(y),stratify=y,test_size = 0.2,random_state=777,shuffle=True)

# %%
from keras.layers import Dense, Dropout, Flatten, Conv1D, Input, MaxPooling1D
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
K.clear_session()

inputs = Input(shape=(8000,1))
Conv1D
#First Conv1D layer
conv = Conv1D(8,13, padding='valid', activation='relu', strides=1)(inputs)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.2)(conv)

#Second Conv1D layer
conv = Conv1D(16, 11, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.2)(conv)

#Third Conv1D layer
conv = Conv1D(32, 9, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.2)(conv)

#Fourth Conv1D layer
conv = Conv1D(64, 7, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.2)(conv)


#Fifth Conv1D layer
conv = Conv1D(128, 5, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.2)(conv)

#Sixth Conv1D layer
conv = Conv1D(256, 3, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.2)(conv)

#Flatten layer
conv = Flatten()(conv)

#Dense Layer 1
conv = Dense(256, activation='relu')(conv)
conv = Dropout(0.2)(conv)

#Dense Layer 2
conv = Dense(128, activation='relu')(conv)
conv = Dropout(0.2)(conv)

outputs = Dense(len(labels), activation='softmax')(conv)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 8000, 1)]         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 7988, 8)           112
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 2662, 8)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 2662, 8)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 2652, 16)          1424
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 884, 16)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 884, 16)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 876, 32)           4640
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 292, 32)           0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 292, 32)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 286, 64)           14400
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 95, 64)            0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 95, 64)            0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 91, 128)           41088
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 30, 128)           0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 30, 128)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 28, 256)           98560
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 9, 256)            0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 9, 256)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               590080
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 784,490
# Trainable params: 784,490
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer='sgd',metrics=['accuracy'])

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20, min_delta=0.00001) 
mc = ModelCheckpoint('best_model.hdf5', monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# %%
history=model.fit(x_tr, y_tr ,epochs=200, callbacks=[es,mc], batch_size=32, validation_data=(x_val,y_val))
# Out:
# Epoch 1/200
# 533/533 [==============================] - 6s 10ms/step - loss: 2.3024 - accuracy: 0.1096 - val_loss: 2.3012 - val_accuracy: 0.1149
#
# Epoch 00001: val_accuracy improved from -inf to 0.11494, saving model to best_model.hdf5
# Epoch 2/200
# 533/533 [==============================] - 5s 9ms/step - loss: 2.2999 - accuracy: 0.1160 - val_loss: 2.2996 - val_accuracy: 0.1283
#
# Epoch 00002: val_accuracy improved from 0.11494 to 0.12831, saving model to best_model.hdf5
# Epoch 3/200
# 533/533 [==============================] - 5s 9ms/step - loss: 2.2961 - accuracy: 0.1235 - val_loss: 2.2951 - val_accuracy: 0.1328
#
# Epoch 00003: val_accuracy improved from 0.12831 to 0.13277, saving model to best_model.hdf5
# Epoch 4/200
# 533/533 [==============================] - 5s 9ms/step - loss: 2.2881 - accuracy: 0.1294 - val_loss: 2.2858 - val_accuracy: 0.1307
#
# Epoch 00004: val_accuracy did not improve from 0.13277
# Epoch 5/200
# 533/533 [==============================] - 5s 9ms/step - loss: 2.2763 - accuracy: 0.1343 - val_loss: 2.2709 - val_accuracy: 0.1504
#
# Epoch 00005: val_accuracy improved from 0.13277 to 0.15036, saving model to best_model.hdf5
# Epoch 6/200
# 533/533 [==============================] - 5s 9ms/step - loss: 2.2621 - accuracy: 0.1430 - val_loss: 2.2532 - val_accuracy: 0.1614
#
# Epoch 00006: val_accuracy improved from 0.15036 to 0.16139, saving model to best_model.hdf5
# Epoch 7/200
# 533/533 [==============================] - 5s 9ms/step - loss: 2.2419 - accuracy: 0.1627 - val_loss: 2.2127 - val_accuracy: 0.1729
#
# Epoch 00007: val_accuracy improved from 0.16139 to 0.17288, saving model to best_model.hdf5
# Epoch 8/200
# 533/533 [==============================] - 5s 9ms/step - loss: 2.2084 - accuracy: 0.1762 - val_loss: 2.1793 - val_accuracy: 0.2130
#
# Epoch 00008: val_accuracy improved from 0.17288 to 0.21300, saving model to best_model.hdf5
# Epoch 9/200
# 533/533 [==============================] - 5s 9ms/step - loss: 2.1805 - accuracy: 0.1903 - val_loss: 2.1392 - val_accuracy: 0.2254
#
# Epoch 00009: val_accuracy improved from 0.21300 to 0.22543, saving model to best_model.hdf5
# Epoch 10/200
# 533/533 [==============================] - 5s 9ms/step - loss: 2.1404 - accuracy: 0.1999 - val_loss: 2.1002 - val_accuracy: 0.2325
#
# Epoch 00010: val_accuracy improved from 0.22543 to 0.23247, saving model to best_model.hdf5
# Epoch 11/200
# 533/533 [==============================] - 5s 9ms/step - loss: 2.1085 - accuracy: 0.2141 - val_loss: 2.0738 - val_accuracy: 0.2353
#
# Epoch 00011: val_accuracy improved from 0.23247 to 0.23528, saving model to best_model.hdf5
# Epoch 12/200
# 533/533 [==============================] - 5s 9ms/step - loss: 2.0473 - accuracy: 0.2241 - val_loss: 2.0218 - val_accuracy: 0.2688
#
# Epoch 00012: val_accuracy improved from 0.23528 to 0.26882, saving model to best_model.hdf5
# Epoch 13/200
# 533/533 [==============================] - 5s 9ms/step - loss: 2.0082 - accuracy: 0.2434 - val_loss: 1.9807 - val_accuracy: 0.2698
#
# Epoch 00013: val_accuracy improved from 0.26882 to 0.26976, saving model to best_model.hdf5
# Epoch 14/200
# 533/533 [==============================] - 5s 9ms/step - loss: 1.9384 - accuracy: 0.2649 - val_loss: 1.8936 - val_accuracy: 0.2909
#
# Epoch 00014: val_accuracy improved from 0.26976 to 0.29087, saving model to best_model.hdf5
# Epoch 15/200
# 533/533 [==============================] - 5s 9ms/step - loss: 1.8716 - accuracy: 0.2878 - val_loss: 1.7511 - val_accuracy: 0.3770
#
# Epoch 00015: val_accuracy improved from 0.29087 to 0.37696, saving model to best_model.hdf5
# Epoch 16/200
# 533/533 [==============================] - 5s 9ms/step - loss: 1.7777 - accuracy: 0.3399 - val_loss: 1.6665 - val_accuracy: 0.4063
#
# Epoch 00016: val_accuracy improved from 0.37696 to 0.40629, saving model to best_model.hdf5
# Epoch 17/200
# 533/533 [==============================] - 5s 9ms/step - loss: 1.6979 - accuracy: 0.3682 - val_loss: 1.6412 - val_accuracy: 0.4042
#
# Epoch 00017: val_accuracy did not improve from 0.40629
# Epoch 18/200
# 533/533 [==============================] - 5s 9ms/step - loss: 1.6224 - accuracy: 0.4095 - val_loss: 1.4801 - val_accuracy: 0.4755
#
# Epoch 00018: val_accuracy improved from 0.40629 to 0.47549, saving model to best_model.hdf5
# Epoch 19/200
# 533/533 [==============================] - 5s 9ms/step - loss: 1.5596 - accuracy: 0.4324 - val_loss: 1.4660 - val_accuracy: 0.4736
#
# Epoch 00019: val_accuracy did not improve from 0.47549
# Epoch 20/200
# 533/533 [==============================] - 5s 9ms/step - loss: 1.4525 - accuracy: 0.4778 - val_loss: 1.3453 - val_accuracy: 0.5400
#
# Epoch 00020: val_accuracy improved from 0.47549 to 0.54000, saving model to best_model.hdf5
# Epoch 21/200
# 533/533 [==============================] - 5s 9ms/step - loss: 1.3745 - accuracy: 0.5051 - val_loss: 1.2415 - val_accuracy: 0.5747
#
# Epoch 00021: val_accuracy improved from 0.54000 to 0.57471, saving model to best_model.hdf5
# Epoch 22/200
# 533/533 [==============================] - 5s 9ms/step - loss: 1.3396 - accuracy: 0.5255 - val_loss: 1.1752 - val_accuracy: 0.5876
#
# Epoch 00022: val_accuracy improved from 0.57471 to 0.58761, saving model to best_model.hdf5
# Epoch 23/200
# 533/533 [==============================] - 5s 9ms/step - loss: 1.2847 - accuracy: 0.5393 - val_loss: 1.1309 - val_accuracy: 0.6162
#
# Epoch 00023: val_accuracy improved from 0.58761 to 0.61623, saving model to best_model.hdf5
# Epoch 24/200
# 533/533 [==============================] - 5s 9ms/step - loss: 1.2075 - accuracy: 0.5708 - val_loss: 1.0888 - val_accuracy: 0.6254
#
# Epoch 00024: val_accuracy improved from 0.61623 to 0.62538, saving model to best_model.hdf5
# Epoch 25/200
# 533/533 [==============================] - 5s 9ms/step - loss: 1.1872 - accuracy: 0.5643 - val_loss: 1.0965 - val_accuracy: 0.6200
#
# Epoch 00025: val_accuracy did not improve from 0.62538
# Epoch 26/200
# 533/533 [==============================] - 5s 9ms/step - loss: 1.1367 - accuracy: 0.5946 - val_loss: 1.0545 - val_accuracy: 0.6458
#
# Epoch 00026: val_accuracy improved from 0.62538 to 0.64579, saving model to best_model.hdf5
# Epoch 27/200
# 533/533 [==============================] - 5s 9ms/step - loss: 1.0920 - accuracy: 0.6141 - val_loss: 0.9675 - val_accuracy: 0.6627
#
# Epoch 00027: val_accuracy improved from 0.64579 to 0.66268, saving model to best_model.hdf5
# Epoch 28/200
# 533/533 [==============================] - 5s 9ms/step - loss: 1.0669 - accuracy: 0.6193 - val_loss: 0.9690 - val_accuracy: 0.6474
#
# Epoch 00028: val_accuracy did not improve from 0.66268
# Epoch 29/200
# 533/533 [==============================] - 5s 9ms/step - loss: 1.0562 - accuracy: 0.6268 - val_loss: 0.9140 - val_accuracy: 0.6807
#
# Epoch 00029: val_accuracy improved from 0.66268 to 0.68074, saving model to best_model.hdf5
# Epoch 30/200
# 533/533 [==============================] - 5s 9ms/step - loss: 1.0288 - accuracy: 0.6372 - val_loss: 0.9033 - val_accuracy: 0.6894
#
# Epoch 00030: val_accuracy improved from 0.68074 to 0.68942, saving model to best_model.hdf5
# Epoch 31/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.9963 - accuracy: 0.6444 - val_loss: 0.8739 - val_accuracy: 0.6953
#
# Epoch 00031: val_accuracy improved from 0.68942 to 0.69529, saving model to best_model.hdf5
# Epoch 32/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.9684 - accuracy: 0.6532 - val_loss: 0.8610 - val_accuracy: 0.6953
#
# Epoch 00032: val_accuracy did not improve from 0.69529
# Epoch 33/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.9600 - accuracy: 0.6621 - val_loss: 0.8385 - val_accuracy: 0.7065
#
# Epoch 00033: val_accuracy improved from 0.69529 to 0.70654, saving model to best_model.hdf5
# Epoch 34/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.9224 - accuracy: 0.6715 - val_loss: 0.8258 - val_accuracy: 0.7230
#
# Epoch 00034: val_accuracy improved from 0.70654 to 0.72297, saving model to best_model.hdf5
# Epoch 35/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.9117 - accuracy: 0.6709 - val_loss: 0.8941 - val_accuracy: 0.6772
#
# Epoch 00035: val_accuracy did not improve from 0.72297
# Epoch 36/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.8927 - accuracy: 0.6856 - val_loss: 0.8159 - val_accuracy: 0.7103
#
# Epoch 00036: val_accuracy did not improve from 0.72297
# Epoch 37/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.8755 - accuracy: 0.6846 - val_loss: 0.8001 - val_accuracy: 0.7166
#
# Epoch 00037: val_accuracy did not improve from 0.72297
# Epoch 38/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.8618 - accuracy: 0.6926 - val_loss: 0.8159 - val_accuracy: 0.7030
#
# Epoch 00038: val_accuracy did not improve from 0.72297
# Epoch 39/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.8448 - accuracy: 0.6967 - val_loss: 0.7369 - val_accuracy: 0.7410
#
# Epoch 00039: val_accuracy improved from 0.72297 to 0.74103, saving model to best_model.hdf5
# Epoch 40/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.8246 - accuracy: 0.7051 - val_loss: 0.7829 - val_accuracy: 0.7286
#
# Epoch 00040: val_accuracy did not improve from 0.74103
# Epoch 41/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.8183 - accuracy: 0.7088 - val_loss: 0.7520 - val_accuracy: 0.7359
#
# Epoch 00041: val_accuracy did not improve from 0.74103
# Epoch 42/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.8106 - accuracy: 0.7091 - val_loss: 0.7646 - val_accuracy: 0.7248
#
# Epoch 00042: val_accuracy did not improve from 0.74103
# Epoch 43/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.8040 - accuracy: 0.7124 - val_loss: 0.7705 - val_accuracy: 0.7171
#
# Epoch 00043: val_accuracy did not improve from 0.74103
# Epoch 44/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.7858 - accuracy: 0.7211 - val_loss: 0.7857 - val_accuracy: 0.7190
#
# Epoch 00044: val_accuracy did not improve from 0.74103
# Epoch 45/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.7888 - accuracy: 0.7199 - val_loss: 0.6945 - val_accuracy: 0.7567
#
# Epoch 00045: val_accuracy improved from 0.74103 to 0.75674, saving model to best_model.hdf5
# Epoch 46/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.7640 - accuracy: 0.7297 - val_loss: 0.7076 - val_accuracy: 0.7478
#
# Epoch 00046: val_accuracy did not improve from 0.75674
# Epoch 47/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.7655 - accuracy: 0.7288 - val_loss: 0.6959 - val_accuracy: 0.7546
#
# Epoch 00047: val_accuracy did not improve from 0.75674
# Epoch 48/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.7510 - accuracy: 0.7345 - val_loss: 0.6818 - val_accuracy: 0.7603
#
# Epoch 00048: val_accuracy improved from 0.75674 to 0.76026, saving model to best_model.hdf5
# Epoch 49/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.7314 - accuracy: 0.7413 - val_loss: 0.6780 - val_accuracy: 0.7624
#
# Epoch 00049: val_accuracy improved from 0.76026 to 0.76237, saving model to best_model.hdf5
# Epoch 50/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.7276 - accuracy: 0.7421 - val_loss: 0.6835 - val_accuracy: 0.7567
#
# Epoch 00050: val_accuracy did not improve from 0.76237
# Epoch 51/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.7138 - accuracy: 0.7482 - val_loss: 0.6933 - val_accuracy: 0.7537
#
# Epoch 00051: val_accuracy did not improve from 0.76237
# Epoch 52/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.7142 - accuracy: 0.7444 - val_loss: 0.6817 - val_accuracy: 0.7614
#
# Epoch 00052: val_accuracy did not improve from 0.76237
# Epoch 53/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.7123 - accuracy: 0.7496 - val_loss: 0.6368 - val_accuracy: 0.7807
#
# Epoch 00053: val_accuracy improved from 0.76237 to 0.78067, saving model to best_model.hdf5
# Epoch 54/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.6886 - accuracy: 0.7595 - val_loss: 0.6642 - val_accuracy: 0.7685
#
# Epoch 00054: val_accuracy did not improve from 0.78067
# Epoch 55/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.6732 - accuracy: 0.7627 - val_loss: 0.6583 - val_accuracy: 0.7708
#
# Epoch 00055: val_accuracy did not improve from 0.78067
# Epoch 56/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.6813 - accuracy: 0.7621 - val_loss: 0.6800 - val_accuracy: 0.7605
#
# Epoch 00056: val_accuracy did not improve from 0.78067
# Epoch 57/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.6737 - accuracy: 0.7612 - val_loss: 0.6256 - val_accuracy: 0.7833
#
# Epoch 00057: val_accuracy improved from 0.78067 to 0.78325, saving model to best_model.hdf5
# Epoch 58/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.6512 - accuracy: 0.7702 - val_loss: 0.6313 - val_accuracy: 0.7804
#
# Epoch 00058: val_accuracy did not improve from 0.78325
# Epoch 59/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.6498 - accuracy: 0.7693 - val_loss: 0.6062 - val_accuracy: 0.7884
#
# Epoch 00059: val_accuracy improved from 0.78325 to 0.78841, saving model to best_model.hdf5
# Epoch 60/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.6421 - accuracy: 0.7690 - val_loss: 0.6162 - val_accuracy: 0.7842
#
# Epoch 00060: val_accuracy did not improve from 0.78841
# Epoch 61/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.6442 - accuracy: 0.7717 - val_loss: 0.6199 - val_accuracy: 0.7861
#
# Epoch 00061: val_accuracy did not improve from 0.78841
# Epoch 62/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.6256 - accuracy: 0.7832 - val_loss: 0.5995 - val_accuracy: 0.7924
#
# Epoch 00062: val_accuracy improved from 0.78841 to 0.79240, saving model to best_model.hdf5
# Epoch 63/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.6071 - accuracy: 0.7860 - val_loss: 0.6041 - val_accuracy: 0.7896
#
# Epoch 00063: val_accuracy did not improve from 0.79240
# Epoch 64/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.6125 - accuracy: 0.7881 - val_loss: 0.5929 - val_accuracy: 0.7990
#
# Epoch 00064: val_accuracy improved from 0.79240 to 0.79897, saving model to best_model.hdf5
# Epoch 65/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.6074 - accuracy: 0.7888 - val_loss: 0.5928 - val_accuracy: 0.7931
#
# Epoch 00065: val_accuracy did not improve from 0.79897
# Epoch 66/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5935 - accuracy: 0.7905 - val_loss: 0.6268 - val_accuracy: 0.7800
#
# Epoch 00066: val_accuracy did not improve from 0.79897
# Epoch 67/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5809 - accuracy: 0.7930 - val_loss: 0.5802 - val_accuracy: 0.8046
#
# Epoch 00067: val_accuracy improved from 0.79897 to 0.80460, saving model to best_model.hdf5
# Epoch 68/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5990 - accuracy: 0.7926 - val_loss: 0.5825 - val_accuracy: 0.7990
#
# Epoch 00068: val_accuracy did not improve from 0.80460
# Epoch 69/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5773 - accuracy: 0.7920 - val_loss: 0.5804 - val_accuracy: 0.8013
#
# Epoch 00069: val_accuracy did not improve from 0.80460
# Epoch 70/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5867 - accuracy: 0.7904 - val_loss: 0.5861 - val_accuracy: 0.7959
#
# Epoch 00070: val_accuracy did not improve from 0.80460
# Epoch 71/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5665 - accuracy: 0.7952 - val_loss: 0.5724 - val_accuracy: 0.8018
#
# Epoch 00071: val_accuracy did not improve from 0.80460
# Epoch 72/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5653 - accuracy: 0.7999 - val_loss: 0.5674 - val_accuracy: 0.8109
#
# Epoch 00072: val_accuracy improved from 0.80460 to 0.81093, saving model to best_model.hdf5
# Epoch 73/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5561 - accuracy: 0.8038 - val_loss: 0.5567 - val_accuracy: 0.8130
#
# Epoch 00073: val_accuracy improved from 0.81093 to 0.81304, saving model to best_model.hdf5
# Epoch 74/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5486 - accuracy: 0.8023 - val_loss: 0.5658 - val_accuracy: 0.8102
#
# Epoch 00074: val_accuracy did not improve from 0.81304
# Epoch 75/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5568 - accuracy: 0.8025 - val_loss: 0.5429 - val_accuracy: 0.8163
#
# Epoch 00075: val_accuracy improved from 0.81304 to 0.81633, saving model to best_model.hdf5
# Epoch 76/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5435 - accuracy: 0.8122 - val_loss: 0.5667 - val_accuracy: 0.8105
#
# Epoch 00076: val_accuracy did not improve from 0.81633
# Epoch 77/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5268 - accuracy: 0.8120 - val_loss: 0.5431 - val_accuracy: 0.8163
#
# Epoch 00077: val_accuracy did not improve from 0.81633
# Epoch 78/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5373 - accuracy: 0.8069 - val_loss: 0.5492 - val_accuracy: 0.8142
#
# Epoch 00078: val_accuracy did not improve from 0.81633
# Epoch 79/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5316 - accuracy: 0.8128 - val_loss: 0.5656 - val_accuracy: 0.8093
#
# Epoch 00079: val_accuracy did not improve from 0.81633
# Epoch 80/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5206 - accuracy: 0.8145 - val_loss: 0.5538 - val_accuracy: 0.8140
#
# Epoch 00080: val_accuracy did not improve from 0.81633
# Epoch 81/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5168 - accuracy: 0.8148 - val_loss: 0.5636 - val_accuracy: 0.8140
#
# Epoch 00081: val_accuracy did not improve from 0.81633
# Epoch 82/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5229 - accuracy: 0.8116 - val_loss: 0.5369 - val_accuracy: 0.8227
#
# Epoch 00082: val_accuracy improved from 0.81633 to 0.82266, saving model to best_model.hdf5
# Epoch 83/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4878 - accuracy: 0.8241 - val_loss: 0.5498 - val_accuracy: 0.8168
#
# Epoch 00083: val_accuracy did not improve from 0.82266
# Epoch 84/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5019 - accuracy: 0.8181 - val_loss: 0.5270 - val_accuracy: 0.8259
#
# Epoch 00084: val_accuracy improved from 0.82266 to 0.82594, saving model to best_model.hdf5
# Epoch 85/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4904 - accuracy: 0.8243 - val_loss: 0.5198 - val_accuracy: 0.8252
#
# Epoch 00085: val_accuracy did not improve from 0.82594
# Epoch 86/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.5006 - accuracy: 0.8221 - val_loss: 0.5406 - val_accuracy: 0.8191
#
# Epoch 00086: val_accuracy did not improve from 0.82594
# Epoch 87/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4770 - accuracy: 0.8300 - val_loss: 0.5282 - val_accuracy: 0.8250
#
# Epoch 00087: val_accuracy did not improve from 0.82594
# Epoch 88/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4961 - accuracy: 0.8239 - val_loss: 0.5376 - val_accuracy: 0.8191
#
# Epoch 00088: val_accuracy did not improve from 0.82594
# Epoch 89/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4794 - accuracy: 0.8267 - val_loss: 0.5708 - val_accuracy: 0.8088
#
# Epoch 00089: val_accuracy did not improve from 0.82594
# Epoch 90/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4777 - accuracy: 0.8319 - val_loss: 0.5468 - val_accuracy: 0.8166
#
# Epoch 00090: val_accuracy did not improve from 0.82594
# Epoch 91/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4809 - accuracy: 0.8257 - val_loss: 0.5180 - val_accuracy: 0.8252
#
# Epoch 00091: val_accuracy did not improve from 0.82594
# Epoch 92/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4545 - accuracy: 0.8396 - val_loss: 0.5569 - val_accuracy: 0.8135
#
# Epoch 00092: val_accuracy did not improve from 0.82594
# Epoch 93/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4586 - accuracy: 0.8376 - val_loss: 0.5164 - val_accuracy: 0.8259
#
# Epoch 00093: val_accuracy did not improve from 0.82594
# Epoch 94/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4673 - accuracy: 0.8329 - val_loss: 0.5002 - val_accuracy: 0.8309
#
# Epoch 00094: val_accuracy improved from 0.82594 to 0.83087, saving model to best_model.hdf5
# Epoch 95/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4492 - accuracy: 0.8402 - val_loss: 0.5105 - val_accuracy: 0.8311
#
# Epoch 00095: val_accuracy improved from 0.83087 to 0.83110, saving model to best_model.hdf5
# Epoch 96/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4561 - accuracy: 0.8386 - val_loss: 0.5317 - val_accuracy: 0.8213
#
# Epoch 00096: val_accuracy did not improve from 0.83110
# Epoch 97/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4465 - accuracy: 0.8366 - val_loss: 0.5282 - val_accuracy: 0.8213
#
# Epoch 00097: val_accuracy did not improve from 0.83110
# Epoch 98/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4346 - accuracy: 0.8409 - val_loss: 0.5197 - val_accuracy: 0.8274
#
# Epoch 00098: val_accuracy did not improve from 0.83110
# Epoch 99/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4431 - accuracy: 0.8439 - val_loss: 0.5137 - val_accuracy: 0.8262
#
# Epoch 00099: val_accuracy did not improve from 0.83110
# Epoch 100/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4175 - accuracy: 0.8492 - val_loss: 0.4990 - val_accuracy: 0.8346
#
# Epoch 00100: val_accuracy improved from 0.83110 to 0.83462, saving model to best_model.hdf5
# Epoch 101/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4270 - accuracy: 0.8508 - val_loss: 0.5241 - val_accuracy: 0.8252
#
# Epoch 00101: val_accuracy did not improve from 0.83462
# Epoch 102/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4169 - accuracy: 0.8556 - val_loss: 0.5235 - val_accuracy: 0.8231
#
# Epoch 00102: val_accuracy did not improve from 0.83462
# Epoch 103/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4127 - accuracy: 0.8513 - val_loss: 0.5358 - val_accuracy: 0.8194
#
# Epoch 00103: val_accuracy did not improve from 0.83462
# Epoch 104/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4339 - accuracy: 0.8459 - val_loss: 0.5078 - val_accuracy: 0.8346
#
# Epoch 00104: val_accuracy did not improve from 0.83462
# Epoch 105/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4154 - accuracy: 0.8537 - val_loss: 0.5634 - val_accuracy: 0.8126
#
# Epoch 00105: val_accuracy did not improve from 0.83462
# Epoch 106/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4197 - accuracy: 0.8484 - val_loss: 0.5293 - val_accuracy: 0.8243
#
# Epoch 00106: val_accuracy did not improve from 0.83462
# Epoch 107/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4160 - accuracy: 0.8496 - val_loss: 0.5101 - val_accuracy: 0.8259
#
# Epoch 00107: val_accuracy did not improve from 0.83462
# Epoch 108/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3992 - accuracy: 0.8610 - val_loss: 0.5317 - val_accuracy: 0.8252
#
# Epoch 00108: val_accuracy did not improve from 0.83462
# Epoch 109/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.4042 - accuracy: 0.8604 - val_loss: 0.5238 - val_accuracy: 0.8222
#
# Epoch 00109: val_accuracy did not improve from 0.83462
# Epoch 110/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3928 - accuracy: 0.8585 - val_loss: 0.5145 - val_accuracy: 0.8283
#
# Epoch 00110: val_accuracy did not improve from 0.83462
# Epoch 111/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3868 - accuracy: 0.8608 - val_loss: 0.5130 - val_accuracy: 0.8320
#
# Epoch 00111: val_accuracy did not improve from 0.83462
# Epoch 112/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3942 - accuracy: 0.8648 - val_loss: 0.4796 - val_accuracy: 0.8393
#
# Epoch 00112: val_accuracy improved from 0.83462 to 0.83932, saving model to best_model.hdf5
# Epoch 113/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3855 - accuracy: 0.8645 - val_loss: 0.4971 - val_accuracy: 0.8316
#
# Epoch 00113: val_accuracy did not improve from 0.83932
# Epoch 114/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3769 - accuracy: 0.8653 - val_loss: 0.4699 - val_accuracy: 0.8428
#
# Epoch 00114: val_accuracy improved from 0.83932 to 0.84283, saving model to best_model.hdf5
# Epoch 115/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3772 - accuracy: 0.8628 - val_loss: 0.4936 - val_accuracy: 0.8360
#
# Epoch 00115: val_accuracy did not improve from 0.84283
# Epoch 116/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3882 - accuracy: 0.8637 - val_loss: 0.4903 - val_accuracy: 0.8419
#
# Epoch 00116: val_accuracy did not improve from 0.84283
# Epoch 117/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3719 - accuracy: 0.8662 - val_loss: 0.4878 - val_accuracy: 0.8400
#
# Epoch 00117: val_accuracy did not improve from 0.84283
# Epoch 118/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3649 - accuracy: 0.8707 - val_loss: 0.4810 - val_accuracy: 0.8435
#
# Epoch 00118: val_accuracy improved from 0.84283 to 0.84354, saving model to best_model.hdf5
# Epoch 119/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3754 - accuracy: 0.8664 - val_loss: 0.4988 - val_accuracy: 0.8367
#
# Epoch 00119: val_accuracy did not improve from 0.84354
# Epoch 120/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3570 - accuracy: 0.8691 - val_loss: 0.5053 - val_accuracy: 0.8309
#
# Epoch 00120: val_accuracy did not improve from 0.84354
# Epoch 121/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3578 - accuracy: 0.8765 - val_loss: 0.4821 - val_accuracy: 0.8410
#
# Epoch 00121: val_accuracy did not improve from 0.84354
# Epoch 122/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3559 - accuracy: 0.8746 - val_loss: 0.4827 - val_accuracy: 0.8417
#
# Epoch 00122: val_accuracy did not improve from 0.84354
# Epoch 123/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3421 - accuracy: 0.8735 - val_loss: 0.4923 - val_accuracy: 0.8367
#
# Epoch 00123: val_accuracy did not improve from 0.84354
# Epoch 124/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3447 - accuracy: 0.8801 - val_loss: 0.4930 - val_accuracy: 0.8367
#
# Epoch 00124: val_accuracy did not improve from 0.84354
# Epoch 125/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3526 - accuracy: 0.8767 - val_loss: 0.4544 - val_accuracy: 0.8454
#
# Epoch 00125: val_accuracy improved from 0.84354 to 0.84541, saving model to best_model.hdf5
# Epoch 126/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3429 - accuracy: 0.8766 - val_loss: 0.5626 - val_accuracy: 0.8098
#
# Epoch 00126: val_accuracy did not improve from 0.84541
# Epoch 127/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3481 - accuracy: 0.8740 - val_loss: 0.4867 - val_accuracy: 0.8421
#
# Epoch 00127: val_accuracy did not improve from 0.84541
# Epoch 128/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3364 - accuracy: 0.8801 - val_loss: 0.4809 - val_accuracy: 0.8407
#
# Epoch 00128: val_accuracy did not improve from 0.84541
# Epoch 129/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3494 - accuracy: 0.8782 - val_loss: 0.4656 - val_accuracy: 0.8466
#
# Epoch 00129: val_accuracy improved from 0.84541 to 0.84659, saving model to best_model.hdf5
# Epoch 130/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3305 - accuracy: 0.8869 - val_loss: 0.4664 - val_accuracy: 0.8426
#
# Epoch 00130: val_accuracy did not improve from 0.84659
# Epoch 131/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3240 - accuracy: 0.8823 - val_loss: 0.4945 - val_accuracy: 0.8381
#
# Epoch 00131: val_accuracy did not improve from 0.84659
# Epoch 132/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3362 - accuracy: 0.8792 - val_loss: 0.4681 - val_accuracy: 0.8466
#
# Epoch 00132: val_accuracy did not improve from 0.84659
# Epoch 133/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3314 - accuracy: 0.8832 - val_loss: 0.5011 - val_accuracy: 0.8372
#
# Epoch 00133: val_accuracy did not improve from 0.84659
# Epoch 134/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3255 - accuracy: 0.8812 - val_loss: 0.4891 - val_accuracy: 0.8414
#
# Epoch 00134: val_accuracy did not improve from 0.84659
# Epoch 135/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3212 - accuracy: 0.8856 - val_loss: 0.4597 - val_accuracy: 0.8517
#
# Epoch 00135: val_accuracy improved from 0.84659 to 0.85175, saving model to best_model.hdf5
# Epoch 136/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3153 - accuracy: 0.8893 - val_loss: 0.4828 - val_accuracy: 0.8431
#
# Epoch 00136: val_accuracy did not improve from 0.85175
# Epoch 137/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3301 - accuracy: 0.8818 - val_loss: 0.4663 - val_accuracy: 0.8536
#
# Epoch 00137: val_accuracy improved from 0.85175 to 0.85362, saving model to best_model.hdf5
# Epoch 138/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3098 - accuracy: 0.8903 - val_loss: 0.4547 - val_accuracy: 0.8489
#
# Epoch 00138: val_accuracy did not improve from 0.85362
# Epoch 139/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3101 - accuracy: 0.8867 - val_loss: 0.4954 - val_accuracy: 0.8391
#
# Epoch 00139: val_accuracy did not improve from 0.85362
# Epoch 140/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3065 - accuracy: 0.8872 - val_loss: 0.4578 - val_accuracy: 0.8536
#
# Epoch 00140: val_accuracy did not improve from 0.85362
# Epoch 141/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2954 - accuracy: 0.8918 - val_loss: 0.4975 - val_accuracy: 0.8405
#
# Epoch 00141: val_accuracy did not improve from 0.85362
# Epoch 142/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.3028 - accuracy: 0.8892 - val_loss: 0.4763 - val_accuracy: 0.8445
#
# Epoch 00142: val_accuracy did not improve from 0.85362
# Epoch 143/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2980 - accuracy: 0.8979 - val_loss: 0.4652 - val_accuracy: 0.8541
#
# Epoch 00143: val_accuracy improved from 0.85362 to 0.85409, saving model to best_model.hdf5
# Epoch 144/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2966 - accuracy: 0.8937 - val_loss: 0.4524 - val_accuracy: 0.8557
#
# Epoch 00144: val_accuracy improved from 0.85409 to 0.85574, saving model to best_model.hdf5
# Epoch 145/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2871 - accuracy: 0.8962 - val_loss: 0.4782 - val_accuracy: 0.8471
#
# Epoch 00145: val_accuracy did not improve from 0.85574
# Epoch 146/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2863 - accuracy: 0.8989 - val_loss: 0.4729 - val_accuracy: 0.8506
#
# Epoch 00146: val_accuracy did not improve from 0.85574
# Epoch 147/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2797 - accuracy: 0.9030 - val_loss: 0.4383 - val_accuracy: 0.8607
#
# Epoch 00147: val_accuracy improved from 0.85574 to 0.86066, saving model to best_model.hdf5
# Epoch 148/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2902 - accuracy: 0.8972 - val_loss: 0.4656 - val_accuracy: 0.8541
#
# Epoch 00148: val_accuracy did not improve from 0.86066
# Epoch 149/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2834 - accuracy: 0.9000 - val_loss: 0.4770 - val_accuracy: 0.8492
#
# Epoch 00149: val_accuracy did not improve from 0.86066
# Epoch 150/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2882 - accuracy: 0.8942 - val_loss: 0.4602 - val_accuracy: 0.8562
#
# Epoch 00150: val_accuracy did not improve from 0.86066
# Epoch 151/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2793 - accuracy: 0.8986 - val_loss: 0.5427 - val_accuracy: 0.8281
#
# Epoch 00151: val_accuracy did not improve from 0.86066
# Epoch 152/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2773 - accuracy: 0.8974 - val_loss: 0.4555 - val_accuracy: 0.8569
#
# Epoch 00152: val_accuracy did not improve from 0.86066
# Epoch 153/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2726 - accuracy: 0.9031 - val_loss: 0.4703 - val_accuracy: 0.8534
#
# Epoch 00153: val_accuracy did not improve from 0.86066
# Epoch 154/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2709 - accuracy: 0.9020 - val_loss: 0.4437 - val_accuracy: 0.8593
#
# Epoch 00154: val_accuracy did not improve from 0.86066
# Epoch 155/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2655 - accuracy: 0.9044 - val_loss: 0.4710 - val_accuracy: 0.8438
#
# Epoch 00155: val_accuracy did not improve from 0.86066
# Epoch 156/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2676 - accuracy: 0.9051 - val_loss: 0.4653 - val_accuracy: 0.8468
#
# Epoch 00156: val_accuracy did not improve from 0.86066
# Epoch 157/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2546 - accuracy: 0.9064 - val_loss: 0.4651 - val_accuracy: 0.8496
#
# Epoch 00157: val_accuracy did not improve from 0.86066
# Epoch 158/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2612 - accuracy: 0.9076 - val_loss: 0.4423 - val_accuracy: 0.8600
#
# Epoch 00158: val_accuracy did not improve from 0.86066
# Epoch 159/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2733 - accuracy: 0.9068 - val_loss: 0.4615 - val_accuracy: 0.8475
#
# Epoch 00159: val_accuracy did not improve from 0.86066
# Epoch 160/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2700 - accuracy: 0.9044 - val_loss: 0.4598 - val_accuracy: 0.8506
#
# Epoch 00160: val_accuracy did not improve from 0.86066
# Epoch 161/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2727 - accuracy: 0.9033 - val_loss: 0.4477 - val_accuracy: 0.8576
#
# Epoch 00161: val_accuracy did not improve from 0.86066
# Epoch 162/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2499 - accuracy: 0.9099 - val_loss: 0.4664 - val_accuracy: 0.8475
#
# Epoch 00162: val_accuracy did not improve from 0.86066
# Epoch 163/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2614 - accuracy: 0.9113 - val_loss: 0.4697 - val_accuracy: 0.8515
#
# Epoch 00163: val_accuracy did not improve from 0.86066
# Epoch 164/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2531 - accuracy: 0.9090 - val_loss: 0.4361 - val_accuracy: 0.8553
#
# Epoch 00164: val_accuracy did not improve from 0.86066
# Epoch 165/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2534 - accuracy: 0.9121 - val_loss: 0.4604 - val_accuracy: 0.8478
#
# Epoch 00165: val_accuracy did not improve from 0.86066
# Epoch 166/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2543 - accuracy: 0.9061 - val_loss: 0.4635 - val_accuracy: 0.8541
#
# Epoch 00166: val_accuracy did not improve from 0.86066
# Epoch 167/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2487 - accuracy: 0.9096 - val_loss: 0.4782 - val_accuracy: 0.8421
#
# Epoch 00167: val_accuracy did not improve from 0.86066
# Epoch 168/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2469 - accuracy: 0.9102 - val_loss: 0.4404 - val_accuracy: 0.8607
#
# Epoch 00168: val_accuracy did not improve from 0.86066
# Epoch 169/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2460 - accuracy: 0.9128 - val_loss: 0.4665 - val_accuracy: 0.8525
#
# Epoch 00169: val_accuracy did not improve from 0.86066
# Epoch 170/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2419 - accuracy: 0.9166 - val_loss: 0.4467 - val_accuracy: 0.8569
#
# Epoch 00170: val_accuracy did not improve from 0.86066
# Epoch 171/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2525 - accuracy: 0.9143 - val_loss: 0.4572 - val_accuracy: 0.8567
#
# Epoch 00171: val_accuracy did not improve from 0.86066
# Epoch 172/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2330 - accuracy: 0.9181 - val_loss: 0.4430 - val_accuracy: 0.8550
#
# Epoch 00172: val_accuracy did not improve from 0.86066
# Epoch 173/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2434 - accuracy: 0.9103 - val_loss: 0.4732 - val_accuracy: 0.8539
#
# Epoch 00173: val_accuracy did not improve from 0.86066
# Epoch 174/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2407 - accuracy: 0.9142 - val_loss: 0.4355 - val_accuracy: 0.8616
#
# Epoch 00174: val_accuracy improved from 0.86066 to 0.86160, saving model to best_model.hdf5
# Epoch 175/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2459 - accuracy: 0.9130 - val_loss: 0.4249 - val_accuracy: 0.8607
#
# Epoch 00175: val_accuracy did not improve from 0.86160
# Epoch 176/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2364 - accuracy: 0.9174 - val_loss: 0.4447 - val_accuracy: 0.8642
#
# Epoch 00176: val_accuracy improved from 0.86160 to 0.86418, saving model to best_model.hdf5
# Epoch 177/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2319 - accuracy: 0.9174 - val_loss: 0.4639 - val_accuracy: 0.8534
#
# Epoch 00177: val_accuracy did not improve from 0.86418
# Epoch 178/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2309 - accuracy: 0.9206 - val_loss: 0.4614 - val_accuracy: 0.8541
#
# Epoch 00178: val_accuracy did not improve from 0.86418
# Epoch 179/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2279 - accuracy: 0.9165 - val_loss: 0.4543 - val_accuracy: 0.8602
#
# Epoch 00179: val_accuracy did not improve from 0.86418
# Epoch 180/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2368 - accuracy: 0.9170 - val_loss: 0.4781 - val_accuracy: 0.8496
#
# Epoch 00180: val_accuracy did not improve from 0.86418
# Epoch 181/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2251 - accuracy: 0.9188 - val_loss: 0.4529 - val_accuracy: 0.8616
#
# Epoch 00181: val_accuracy did not improve from 0.86418
# Epoch 182/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2210 - accuracy: 0.9229 - val_loss: 0.4317 - val_accuracy: 0.8668
#
# Epoch 00182: val_accuracy improved from 0.86418 to 0.86676, saving model to best_model.hdf5
# Epoch 183/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2123 - accuracy: 0.9233 - val_loss: 0.4635 - val_accuracy: 0.8541
#
# Epoch 00183: val_accuracy did not improve from 0.86676
# Epoch 184/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2291 - accuracy: 0.9166 - val_loss: 0.4424 - val_accuracy: 0.8635
#
# Epoch 00184: val_accuracy did not improve from 0.86676
# Epoch 185/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2245 - accuracy: 0.9191 - val_loss: 0.4540 - val_accuracy: 0.8571
#
# Epoch 00185: val_accuracy did not improve from 0.86676
# Epoch 186/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2124 - accuracy: 0.9234 - val_loss: 0.4405 - val_accuracy: 0.8642
#
# Epoch 00186: val_accuracy did not improve from 0.86676
# Epoch 187/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2258 - accuracy: 0.9207 - val_loss: 0.4668 - val_accuracy: 0.8548
#
# Epoch 00187: val_accuracy did not improve from 0.86676
# Epoch 188/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2154 - accuracy: 0.9225 - val_loss: 0.4249 - val_accuracy: 0.8693
#
# Epoch 00188: val_accuracy improved from 0.86676 to 0.86934, saving model to best_model.hdf5
# Epoch 189/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2134 - accuracy: 0.9242 - val_loss: 0.4583 - val_accuracy: 0.8625
#
# Epoch 00189: val_accuracy did not improve from 0.86934
# Epoch 190/200
# 533/533 [==============================] - 5s 9ms/step - loss: 0.2151 - accuracy: 0.9250 - val_loss: 0.4413 - val_accuracy: 0.8658
#
# Epoch 00190: val_accuracy did not improve from 0.86934
# Epoch 191/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2057 - accuracy: 0.9232 - val_loss: 0.4168 - val_accuracy: 0.8707
#
# Epoch 00191: val_accuracy improved from 0.86934 to 0.87075, saving model to best_model.hdf5
# Epoch 192/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2174 - accuracy: 0.9263 - val_loss: 0.4546 - val_accuracy: 0.8602
#
# Epoch 00192: val_accuracy did not improve from 0.87075
# Epoch 193/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2146 - accuracy: 0.9216 - val_loss: 0.4689 - val_accuracy: 0.8583
#
# Epoch 00193: val_accuracy did not improve from 0.87075
# Epoch 194/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2131 - accuracy: 0.9223 - val_loss: 0.4233 - val_accuracy: 0.8686
#
# Epoch 00194: val_accuracy did not improve from 0.87075
# Epoch 195/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2017 - accuracy: 0.9276 - val_loss: 0.4928 - val_accuracy: 0.8496
#
# Epoch 00195: val_accuracy did not improve from 0.87075
# Epoch 196/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2133 - accuracy: 0.9233 - val_loss: 0.4518 - val_accuracy: 0.8663
#
# Epoch 00196: val_accuracy did not improve from 0.87075
# Epoch 197/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2096 - accuracy: 0.9222 - val_loss: 0.4462 - val_accuracy: 0.8710
#
# Epoch 00197: val_accuracy improved from 0.87075 to 0.87098, saving model to best_model.hdf5
# Epoch 198/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2028 - accuracy: 0.9284 - val_loss: 0.4617 - val_accuracy: 0.8639
#
# Epoch 00198: val_accuracy did not improve from 0.87098
# Epoch 199/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2021 - accuracy: 0.9279 - val_loss: 0.4444 - val_accuracy: 0.8644
#
# Epoch 00199: val_accuracy did not improve from 0.87098
# Epoch 200/200
# 533/533 [==============================] - 5s 10ms/step - loss: 0.2029 - accuracy: 0.9329 - val_loss: 0.4309 - val_accuracy: 0.8712
#
# Epoch 00200: val_accuracy improved from 0.87098 to 0.87122, saving model to best_model.hdf5

# %%
from matplotlib import pyplot 
pyplot.plot(history.history['loss'], label='train') 
pyplot.plot(history.history['val_loss'], label='test') 

pyplot.plot(history.history['accuracy'], label='train') 
pyplot.plot(history.history['val_accuracy'], label='test') 

pyplot.legend()
pyplot.show()

# %%
def predict(audio):
    prob=model.predict(audio.reshape(1,8000,1))
    index=np.argmax(prob[0])
    return classes[index]

# %%
import random
index=random.randint(0,len(x_val)-1)
samples=x_val[index].ravel()
print("Audio:",classes[np.argmax(y_val[index])])
ipd.Audio(samples, rate=8000)
print("Text:",predict(samples))
# Out:
# Audio: stop
# Text: stop
